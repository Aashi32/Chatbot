# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashi32/Chatbot/blob/main/chatbot1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ### Adding question column to dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Mental_health/Category_wise_data/SuicidalWatch_data/CombinedSuicideWatch.csv")

# %%
df = df.drop('label', axis=1)

# %%
df.head(2)
# Out:
#                                                 text
# 0  I'm sure I won't make it to 2019 I'm just a br...
# 1  I've made up my mind and going through with su...

# %%
# Specify the path to the .txt file
file_path = '/content/drive/MyDrive/Mental_health/Category_wise_data/SuicidalWatch_data/QuestionsSuicideWatch.txt'

# %%
# Read the file into a DataFrame
# Adjust parameters (like delimiter) as needed based on file structure
df1 = pd.read_csv(file_path, delimiter='\t')  # Use appropriate delimiter

df1.head()
# Out:
#                                             question
# 0  Can you provide a sentence that someone might ...
# 1  What is an example of a statement made by a pe...
# 2  Give me an example of what someone might say i...
# 3  Can you share a sentence that indicates a pers...
# 4  Provide an example of a statement from a perso...

# %% [markdown]
# # for depression

# %%
dep = pd.read_csv("/content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/CombinedDepression.csv")

# %%
dep = dep.drop('label', axis=1)

# %%
dep.head()
# Out:
#                                                 text
# 0  we understand that most people who reply immed...
# 1  welcome to r depression s check in post a plac...
# 2  anyone else instead of sleeping more when depr...
# 3  i ve kind of stuffed around a lot in my life d...
# 4  sleep is my greatest and most comforting escap...

# %%
dep.shape
# Out:
# (23193, 1)

# %%
import random

file_path = '/content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/questions.txt'

# List of questions
questions = [
    "Can you provide an example of a statement from a person under medical treatment for depression?",
    "What is a common emotional state mentioned by people who live alone and are prone to loneliness?",
    "How do some people describe their experience of sleep when they are dealing with depression?",
    "What feelings are expressed by someone who wakes up every day with misery and reminders of their problems?",
    "What do people with depression often struggle with in terms of communication?",
    "How does depression affect someone's ability to get out of bed and take care of their pet?",
    "What are some common thoughts people with depression have about their future?",
    "How do people with depression often feel about their relationships with others?",
    "What is a common fear expressed by someone who feels like a failure and wants to disappear?",
    "What does a person with depression typically say about their energy levels when trying to talk to others?",
    "What kind of relationship do people with depression often crave?",
    "How do people with depression describe their efforts to be a decent human being and fit in?",
    "What feelings do people with depression have about their self-worth and achievements?",
    "How does depression impact someone's ability to hold a job and be a responsible adult?",
    "What are some reasons people with depression might avoid sleeping at night?",
    "How do people with depression feel about sharing their accomplishments in the r/depression community?",
    "Why are posts about difficult emotions like grief and sadness often redirected to other places in the r/depression community?",
    "What does the r/depression wiki provide guidance on regarding depressive disorders?",
    "Why is it unwise to trust someone who offers private contact early in a conversation in the r/depression community?",
    "What is the potential harm of offering a personal inbox as a resource for people with serious mental health issues?",
    "How does community input help mitigate limitations in knowledge and communication when providing support?",
    "Why might people use throwaway accounts in the r/depression community?",
    "What kind of people specifically target those who are vulnerable because of mental health issues?",
    "What tends to be effective when someone is in a state of mental health crisis, according to the text?",
    "Why is it important to carefully look at someone's history before opening up to them in private contact?",
    "What should someone do if they want to request private contact when asking for support in the r/depression community?",
    "How does posting supportive replies publicly help educate and inspire other helpers in the community?",
    "What does the giving help wiki offer information on regarding peer support for mental health issues?",
    "What is a common issue people with depression face regarding their thoughts and emotions?",
    "How do people with depression describe their experience of waking up and facing the day?",
    "What is a common experience of people with depression when it comes to holding a conversation?",
    "What feelings do people with depression often have about their own efforts to treat others with kindness and respect?"
]

# Shuffle questions and repeat to get 23193 rows
rows_needed = 23193
questions_shuffled = questions * (rows_needed // len(questions)) + questions[:rows_needed % len(questions)]
random.shuffle(questions_shuffled)

# Write to .txt file in Google Drive with column name
with open(file_path, 'w') as file:
    file.write("question\n")
    for question in questions_shuffled:
        file.write(f"{question}\n")

print(f"questions.txt file created successfully at {file_path}.")
# Out:
# questions.txt file created successfully at /content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/questions.txt.

# %%
dep2 = pd.read_csv(file_path, delimiter='\t')
dep2.head()
# Out:
#                                             question
# 0  What are some common thoughts people with depr...
# 1  Why are posts about difficult emotions like gr...
# 2  How do some people describe their experience o...
# 3  Why is it unwise to trust someone who offers p...
# 4  What tends to be effective when someone is in ...

# %%
dep_concatenated = pd.concat([dep, dep2], axis=1)

# %%
dep_concatenated.head()
# Out:
#                                                 text  \
# 0  we understand that most people who reply immed...
# 1  welcome to r depression s check in post a plac...
# 2  anyone else instead of sleeping more when depr...
# 3  i ve kind of stuffed around a lot in my life d...
# 4  sleep is my greatest and most comforting escap...
#
#                                             question
# 0  What are some common thoughts people with depr...
# 1  Why are posts about difficult emotions like gr...
# 2  How do some people describe their experience o...
# 3  Why is it unwise to trust someone who offers p...
# 4  What tends to be effective when someone is in ...

# %%
# Specify the path in Google Drive where you want to save the .csv file
file_path = '/content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/DepressionWithQuestion.csv'

# Save the DataFrame to a .csv file
dep_concatenated.to_csv(file_path, index=False)

print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to /content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/DepressionWithQuestion.csv

# %% [markdown]
# ## Concat

# %%
df_concatenated = pd.concat([df1, df], axis=1)

# %%
df_concatenated.head(2)
# Out:
#                                             question  \
# 0  Can you provide a sentence that someone might ...
# 1  What is an example of a statement made by a pe...
#
#                                                 text
# 0  I'm sure I won't make it to 2019 I'm just a br...
# 1  I've made up my mind and going through with su...

# %% [markdown]
# #Anxiety

# %%
df = pd.read_csv("/content/drive/MyDrive/Mental_health/Category_wise_data/SuicidalWatch_data/CombinedSuicideWatch.csv")

# %%
df = df.drop('label', axis=1)

# %%
df
# Out:
#                                                     text
# 0      I'm sure I won't make it to 2019 I'm just a br...
# 1      I've made up my mind and going through with su...
# 2      To weak for suicide I want to die so bad , but...
# 3      I'm so tired. I feel like an empty shell of a ...
# 4      I tell people '' happy new year'' but I'm terr...
# ...                                                  ...
# 66156  I have nothing to make me want to live I know ...
# 66157  If I can’t fix my hair, I’m going to kill myse...
# 66158  The harder I swim the faster I sink Just feel ...
# 66159  Reasons to live I'm not in a good place right ...
# 66160  just wanna die already life is boring and depr...
#
# [66161 rows x 1 columns]

# %%
import random

file_path = '/content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/questions.txt'
questions = [
    "Can you give an example of a sentence said by a person expressing medical anxiety?",
    "What is a sentence that shows a person is suffering from medical anxiety?",
    "Can you provide an example of what someone with medical anxiety might say?",
    "What might a person say if they are experiencing medical anxiety?",
    "How might a person express their medical anxiety in a sentence?",
    "Can you give a sentence that reflects medical anxiety?",
    "What would a person with medical anxiety say?",
    "Can you provide a quote from someone dealing with medical anxiety?",
    "What is an example of a statement from a person with medical anxiety?",
    "Can you give an example of dialogue showing medical anxiety?",
    "What might someone with medical anxiety say in a moment of distress?",
    "How would a person voice their medical anxiety in words?",
    "What is a typical sentence said by someone experiencing medical anxiety?",
    "Can you give an example of what someone anxious about their health might say?",
    "What is an example of a phrase from a person with medical anxiety?",
    "Can you provide an example of a sentence that indicates medical anxiety?",
    "How might someone express their feelings of medical anxiety verbally?",
    "What could a person say if they are suffering from medical anxiety?",
    "Can you give a sentence that demonstrates medical anxiety?",
    "What is something a person with medical anxiety might say?",
    "Can you provide an example of a medical anxiety statement?",
    "What might a person say to express their medical anxiety?",
    "Can you give an example of a medical anxiety expression?",
    "What is a sentence that reflects the thoughts of someone with medical anxiety?",
    "How might someone verbalize their medical anxiety?",
    "Can you provide a sentence that shows someone is anxious about their health?",
    "What could a person with medical anxiety say?",
    "Can you give an example of a sentence spoken by someone with medical anxiety?",
    "How might a person describe their medical anxiety in a sentence?",
    "What is a typical expression of medical anxiety in words?",
    "Can you provide an example of how someone might voice their medical anxiety?",
    "What is an example of a spoken sentence that shows medical anxiety?",
    "Can you give a quote that represents medical anxiety?",
    "How might someone articulate their medical anxiety?",
    "Can you provide a sentence that depicts medical anxiety?",
    "What would a person say to convey their medical anxiety?",
    "Can you give an example of a sentence that reveals medical anxiety?",
    "What is an example of verbalizing medical anxiety?",
    "Can you provide an example of a sentence that expresses medical anxiety?",
    "How might a person express their medical anxiety in a statement?",
    "What is a common sentence said by someone with medical anxiety?",
    "Can you give an example of what a person with medical anxiety might articulate?",
    "How might someone with medical anxiety phrase their feelings?",
    "Can you provide a statement that indicates medical anxiety?",
    "What is an example of a sentence that shows someone is experiencing medical anxiety?",
    "Can you give an example of a verbal expression of medical anxiety?",
    "How might someone with medical anxiety express their fears?",
    "Can you provide an example of a sentence that someone with medical anxiety might say?",
    "What is a sentence that could be said by a person suffering from medical anxiety?",
    "Can you give a sentence that exemplifies medical anxiety?"
]

# Shuffle questions and repeat to get 23193 rows
rows_needed = 66161
questions_shuffled = questions * (rows_needed // len(questions)) + questions[:rows_needed % len(questions)]
random.shuffle(questions_shuffled)

# Write to .txt file in Google Drive with column name
with open(file_path, 'w') as file:
    file.write("question\n")
    for question in questions_shuffled:
        file.write(f"{question}\n")

print(f"questions.txt file created successfully at {file_path}.")
# Out:
# questions.txt file created successfully at /content/drive/MyDrive/Mental_health/Category_wise_data/Depression_data/questions.txt.

# %%
anxiety = pd.read_csv(file_path, delimiter='\t')
anxiety.head()
# Out:
#                                             question
# 0  Can you provide a sentence that depicts medica...
# 1  What might a person say if they are experienci...
# 2  Can you give a quote that represents medical a...
# 3  How might a person describe their medical anxi...
# 4      What would a person with medical anxiety say?

# %%
anxiety_concatenated = pd.concat([df, anxiety], axis=1)

# %%
anxiety_concatenated
# Out:
#                                                     text  \
# 0      I'm sure I won't make it to 2019 I'm just a br...
# 1      I've made up my mind and going through with su...
# 2      To weak for suicide I want to die so bad , but...
# 3      I'm so tired. I feel like an empty shell of a ...
# 4      I tell people '' happy new year'' but I'm terr...
# ...                                                  ...
# 66156  I have nothing to make me want to live I know ...
# 66157  If I can’t fix my hair, I’m going to kill myse...
# 66158  The harder I swim the faster I sink Just feel ...
# 66159  Reasons to live I'm not in a good place right ...
# 66160  just wanna die already life is boring and depr...
#
#                                                 question
# 0      Can you provide a sentence that depicts medica...
# 1      What might a person say if they are experienci...
# 2      Can you give a quote that represents medical a...
# ...

# %%
# Specify the path in Google Drive where you want to save the .csv file
file_path = '/content/drive/MyDrive/Mental_health/Category_wise_data/Anxiety_data/final_anxiety_questions.csv'

# Save the DataFrame to a .csv file
anxiety_concatenated.to_csv(file_path, index=False)

print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to /content/drive/MyDrive/Mental_health/Category_wise_data/Anxiety_data/final_anxiety_questions.csv

# %% [markdown]
# # ###Gradio

# %%
# !pip install transformers

# %%
from tqdm import tqdm

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 34.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.1 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline, Conversation
import gradio as gr

# %%
# # toy example 1
# pipeline(task="sentiment-analysis")("Love this!")

# %%
# # toy example 2
# pipeline(task="sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")("Love this!")

# %% [markdown]
# ## CLassifier (sentiment analysis)

# %%
# defining classifier
classifier = pipeline(task="sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# we can also pass in a list to classifier

# classifier("Wow, it's happening")

text_list = ["This is great", \
             "Thanks for nothing", \
             "You've got to work on your face", \
             "You're beautiful, never change!"]

classifier(text_list)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998785257339478},
#  {'label': 'POSITIVE', 'score': 0.9680058360099792},
#  {'label': 'NEGATIVE', 'score': 0.8776119947433472},
#  {'label': 'POSITIVE', 'score': 0.9998120665550232}]

# %% [markdown]
# ## Multiple Target Labels(text classification)

# %%
# if there are multiple target labels, we can return them all
classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None)
# Out:
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
classifier(text_list[0])
# Out:
# [[{'label': 'admiration', 'score': 0.9526104927062988},
#   {'label': 'approval', 'score': 0.030472073704004288},
#   {'label': 'neutral', 'score': 0.015236238949000835},
#   {'label': 'excitement', 'score': 0.0060637635178864},
#   {'label': 'gratitude', 'score': 0.005296191666275263},
#   {'label': 'joy', 'score': 0.004475213587284088},
#   {'label': 'curiosity', 'score': 0.004322331864386797},
#   {'label': 'realization', 'score': 0.004089601803570986},
#   {'label': 'optimism', 'score': 0.00407722033560276},
#   {'label': 'disapproval', 'score': 0.004076560027897358},
#   {'label': 'annoyance', 'score': 0.0035287411883473396},
#   {'label': 'surprise', 'score': 0.0029730673413723707},
#   {'label': 'disappointment', 'score': 0.002734640846028924},
#   {'label': 'love', 'score': 0.0026945793069899082},
#   {'label': 'amusement', 'score': 0.0024867462925612926},
#   {'label': 'confusion', 'score': 0.0023607409093528986},
#   {'label': 'pride', 'score': 0.0021013361401855946},
# ...

# %% [markdown]
# ## Summarizer

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
text = """
Hugging Face is an AI company that has become a major hub for open-source machine learning.
Their platform has 3 major elements which allow users to access and share machine learning resources.
First, is their rapidly growing repository of pre-trained open-source machine learning models for things such as natural language processing (NLP), computer vision, and more.
Second, is their library of datasets for training machine learning models for almost any task.
Third, and finally, is Spaces which is a collection of open-source ML apps.

The power of these resources is that they are community generated, which leverages all the benefits of open source i.e. cost-free, wide diversity of tools, high quality resources, and rapid pace of innovation.
While these make building powerful ML projects more accessible than before, there is another key element of the Hugging Face ecosystem—their Transformers library.
"""
summarized_text = summarizer(text, min_length=5, max_length=140)[0]['summary_text']
summarized_text
# Out:
# 'Hugging Face is an AI company that has become a major hub for open-source machine learning. The power of these resources is that they are community generated.'

# %%
# classifier(summarized_text)

# %% [markdown]
# ## Chatbot

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
chatbot = pipeline(model="umitmertcakmak/Llama-2-13B-fp16-mental-health-chatbot")
# Out:
# config.json:   0%|          | 0.00/656 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/29.9k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.90G [00:00<?, ?B/s]

# %%
conversation = chatbot("Hi I'm Aashi, how are you?")

# %%
conversation

# %%
conversation = chatbot("what is mental health")

# %%
conversation

# %%
def top3_text_classes(message, history):
    return str(classifier(message)[0][:3]).replace('}, {', '\n').replace('[{', '').replace('}]', '')

demo_sentiment = gr.ChatInterface(top3_text_classes, title="Plain chatbot", description="Feel free to chat")

demo_sentiment.launch()

# %%
def summarizer_bot(message, history):
    return summarizer(message, min_length=5, max_length=140)[0]['summary_text']

demo_summarizer = gr.ChatInterface(summarizer_bot, title="Summarizer Chatbot", description="Enter your text, and the chatbot will return the summarized version.")

demo_summarizer.launch()

# %%
message_list = []
response_list = []

def vanilla_chatbot(message, history):
    conversation = chatbot(message)

    return conversation[0]['generated_text']

demo_chatbot = gr.ChatInterface(vanilla_chatbot, title="Vanilla Chatbot", description="Enter text to start chatting.")

demo_chatbot.launch()
